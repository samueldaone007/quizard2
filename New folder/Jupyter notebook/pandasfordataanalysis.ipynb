# %%
import pandas as pd

# %%
df = pd.read_csv('flights.csv')

# %%
#view the first five rows
df.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
df.shape
# Out:
# (336776, 21)

# %%
df.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
for i in df.columns:
    print (i)
# Out:
# id
# year
# month
# day
# dep_time
# sched_dep_time
# dep_delay
# arr_time
# sched_arr_time
# arr_delay
# carrier
# flight
# tailnum
# origin
# dest
# air_time
# distance
# hour
# minute
# time_hour
# name

# %% [markdown]
# df.info()

# %%
df.isna().sum()
# Out:
# id                   0
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# name                 0
# dtype: int64

# %%
x = 0
for i in df['carrier'].unique():
    x+=1
print(x)
# Out:
# 16

# %%
df['dest'].value_counts().head(10)
# Out:
# dest
# ORD    17283
# ATL    17215
# LAX    16174
# BOS    15508
# MCO    14082
# CLT    14064
# SFO    13331
# FLL    12055
# MIA    11728
# DCA     9705
# Name: count, dtype: int64

# %%
df['flight'].value_counts()
# Out:
# flight
# 15      968
# 27      898
# 181     882
# 301     871
# 161     786
#        ...
# 3464      1
# 1226      1
# 3136      1
# 4953      1
# 3539      1
# Name: count, Length: 3844, dtype: int64

# %%
df['origin'].value_counts()
# Out:
# origin
# EWR    120835
# JFK    111279
# LGA    104662
# Name: count, dtype: int64

# %%
df[df['origin'] == 'JFK']
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 2            2  2013      1    1     542.0             540        2.0
# 3            3  2013      1    1     544.0             545       -1.0
# 8            8  2013      1    1     557.0             600       -3.0
# 10          10  2013      1    1     558.0             600       -2.0
# 11          11  2013      1    1     558.0             600       -2.0
# ...        ...   ...    ...  ...       ...             ...        ...
# 336766  336766  2013      9   30    2240.0            2250      -10.0
# 336767  336767  2013      9   30    2241.0            2246       -5.0
# 336768  336768  2013      9   30    2307.0            2255       12.0
# 336769  336769  2013      9   30    2349.0            2359      -10.0
# 336771  336771  2013      9   30       NaN            1455        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %%
jfks = df[df['origin'] == 'JFK']

# %%
jfks['origin'].value_counts()
# Out:
# origin
# JFK    111279
# Name: count, dtype: int64

# %%
df[df['name'] == 'United Air Lines Inc.']
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2013      1    1     517.0             515        2.0     830.0
# 1       2013      1    1     533.0             529        4.0     850.0
# 5       2013      1    1     554.0             558       -4.0     740.0
# 12      2013      1    1     558.0             600       -2.0     924.0
# 13      2013      1    1     558.0             600       -2.0     923.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336723  2013      9   30    2052.0            2059       -7.0    2315.0
# 336728  2013      9   30    2055.0            2059       -4.0    2158.0
# 336737  2013      9   30    2105.0            2106       -1.0    2329.0
# 336755  2013      9   30    2149.0            2156       -7.0    2245.0
# 336762  2013      9   30    2233.0            2113       80.0     112.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df[df['arr_delay'] >= 60]
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 119        119  2013      1    1     811.0             630      101.0
# 151        151  2013      1    1     848.0            1835      853.0
# 218        218  2013      1    1     957.0             733      144.0
# 268        268  2013      1    1    1114.0             900      134.0
# 269        269  2013      1    1    1120.0             944       96.0
# ...        ...   ...    ...  ...       ...             ...        ...
# 336664  336664  2013      9   30    1943.0            1810       93.0
# 336668  336668  2013      9   30    1951.0            1649      182.0
# 336724  336724  2013      9   30    2053.0            1815      158.0
# 336757  336757  2013      9   30    2159.0            1845      194.0
# 336763  336763  2013      9   30    2235.0            2001      154.0
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %%
df.drop('id', axis = 1, inplace=True)

# %%
df.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
# 1  2013      1    1     533.0             529        4.0     850.0
# 2  2013      1    1     542.0             540        2.0     923.0
# 3  2013      1    1     544.0             545       -1.0    1004.0
# 4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 1             830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 2             850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 3            1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 4             837      -25.0      DL     461  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'dep_time', 'sched_dep_time', 'dep_delay',
#        'arr_time', 'sched_arr_time', 'arr_delay', 'carrier', 'flight',
#        'tailnum', 'origin', 'dest', 'air_time', 'distance', 'hour', 'minute',
#        'time_hour', 'name'],
#       dtype='object')

# %%
df.iloc[:,0:4]
# Out:
#         year  month  day  dep_time
# 0       2013      1    1     517.0
# 1       2013      1    1     533.0
# 2       2013      1    1     542.0
# 3       2013      1    1     544.0
# 4       2013      1    1     554.0
# ...      ...    ...  ...       ...
# 336771  2013      9   30       NaN
# 336772  2013      9   30       NaN
# 336773  2013      9   30       NaN
# 336774  2013      9   30       NaN
# 336775  2013      9   30       NaN
#
# [336776 rows x 4 columns]

# %%
df.loc[:,['day','arr_time','carrier','year']]
# Out:
#         day  arr_time carrier  year
# 0         1     830.0      UA  2013
# 1         1     850.0      UA  2013
# 2         1     923.0      AA  2013
# 3         1    1004.0      B6  2013
# 4         1     812.0      DL  2013
# ...     ...       ...     ...   ...
# 336771   30       NaN      9E  2013
# 336772   30       NaN      9E  2013
# 336773   30       NaN      MQ  2013
# 336774   30       NaN      MQ  2013
# 336775   30       NaN      MQ  2013
#
# [336776 rows x 4 columns]

# %%
#how many years are there in the years column
df['year'].value_counts()
# Out:
# year
# 2013    336776
# Name: count, dtype: int64

# %%
df['month'].value_counts().sort_index()
# Out:
# month
# 1     27004
# 2     24951
# 3     28834
# 4     28330
# 5     28796
# 6     28243
# 7     29425
# 8     29327
# 9     27574
# 10    28889
# 11    27268
# 12    28135
# Name: count, dtype: int64

# %%
meanfordistance=df['distance'].mean()

# %%
meanfordistance
# Out:
# 1039.9126036297123

# %%
df['dep_time'].fillna(df['dep_time'].mean())
# Out:
# 0          517.000000
# 1          533.000000
# 2          542.000000
# 3          544.000000
# 4          554.000000
#              ...
# 336771    1349.109947
# 336772    1349.109947
# 336773    1349.109947
# 336774    1349.109947
# 336775    1349.109947
# Name: dep_time, Length: 336776, dtype: float64

# %%
\
'].mean()
# Out:
# origin
# EWR    15.107954
# JFK    12.112159
# LGA    10.346876
# Name: dep_delay, dtype: float64
